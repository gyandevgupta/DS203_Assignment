# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Links

# %%
url1 = "https://raw.githubusercontent.com/gyandevgupta/DS203_Assignment/master/hmis-operation_minor_no_or_local_anaesthesia-2018-19-wb-Jan_to_Mar.csv"
url2 = "https://raw.githubusercontent.com/gyandevgupta/DS203_Assignment/master/LLY.csv"
url3 = "https://raw.githubusercontent.com/gyandevgupta/DS203_Assignment/master/dataset.csv"

# %% [markdown]
# #Q.1a

# %%
df_a = pd.read_csv(url1)
#printing the first five data sets
df_a.head()
# Out:
#      District  ... No. of facilities by performance - >300
# 0  Alipurduar  ...                                       0
# 1  Alipurduar  ...                                       0
# 2     Bankura  ...                                       2
# 3     Bankura  ...                                       2
# 4     Birbhum  ...                                       2
#
# [5 rows x 11 columns]

# %%
#PRINTING last five data sets 
df_a.tail()
# Out:
#                       District  ... No. of facilities by performance - >300
# 69  South Twenty Four Parganas  ...                                       0
# 70              Uttar Dinajpur  ...                                       1
# 71              Uttar Dinajpur  ...                                       1
# 72              Uttar Dinajpur  ...                                       0
# 73              Uttar Dinajpur  ...                                       0
#
# [5 rows x 11 columns]

# %%
#printing the python data type variable
print(df_a.info())
print("\n")
#printing the column and their unique values
for column in df_a:
  print(column)
  print(df_a[column].unique())
  print("\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 11 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   District                                       74 non-null     object
#  1   Facility Type                                  74 non-null     object
#  2   Total No. of Facilities #                      74 non-null     int64
#  3   No. of facilities reporting nil performance *  74 non-null     int64
#  4   Performance - Overall Average **               74 non-null     int64
#  5   Performance - Maximum                          74 non-null     int64
#  6   Performance - Minimum                          74 non-null     int64
#  7   No. of facilities by performance - 1 to 30     74 non-null     int64
#  8   No. of facilities by performance - 31 to 150   74 non-null     int64
# ...

# %% [markdown]
# #Q.1b

# %%
df_b = pd.read_csv(url2)
#printing the first five data sets
df_b.head()
# Out:
#          Date        Open        High  ...       Close   Adj Close   Volume
# 0  2020-09-01  148.610001  149.199997  ...  147.300003  144.827866  2358700
# 1  2020-09-02  146.789993  150.000000  ...  149.550003  147.040100  2406800
# 2  2020-09-03  152.190002  153.369995  ...  149.020004  146.519012  4226100
# 3  2020-09-04  148.770004  152.580002  ...  150.910004  148.377274  4361800
# 4  2020-09-08  150.949997  151.309998  ...  149.309998  146.804123  4351200
#
# [5 rows x 7 columns]

# %%
df_b.tail()
# Out:
#            Date        Open        High  ...       Close   Adj Close   Volume
# 247  2021-08-25  262.779999  264.519989  ...  263.869995  263.869995  2388500
# 248  2021-08-26  264.000000  265.589996  ...  261.320007  261.320007  1732900
# 249  2021-08-27  262.519989  263.130005  ...  259.750000  259.750000  1839700
# 250  2021-08-30  261.029999  264.070007  ...  262.309998  262.309998  1300700
# 251  2021-08-31  262.839996  263.640015  ...  258.290009  258.290009  2733000
#
# [5 rows x 7 columns]

# %%
#printing the python data type variable
print(df_b.info())
print("\n")
#printing the column and their unique values
for column in df_b:
  print(column)
  print(df_b[column].unique())
  print("\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    object
#  1   Open       252 non-null    float64
#  2   High       252 non-null    float64
#  3   Low        252 non-null    float64
#  4   Close      252 non-null    float64
#  5   Adj Close  252 non-null    float64
#  6   Volume     252 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB
# None
#
#
# Date
# ['2020-09-01' '2020-09-02' '2020-09-03' '2020-09-04' '2020-09-08'
#  '2020-09-09' '2020-09-10' '2020-09-11' '2020-09-14' '2020-09-15'
#  '2020-09-16' '2020-09-17' '2020-09-18' '2020-09-21' '2020-09-22'
#  '2020-09-23' '2020-09-24' '2020-09-25' '2020-09-28' '2020-09-29'
#  '2020-09-30' '2020-10-01' '2020-10-02' '2020-10-05' '2020-10-06'
#  '2020-10-07' '2020-10-08' '2020-10-09' '2020-10-12' '2020-10-13'
# ...

# %% [markdown]
# #Q.1c

# %%
df_c = pd.read_csv(url3,delimiter=";",skiprows=1)
#printing the first five data sets
df_c.head()
# Out:
#    ID Motorway   SR  ...  Tree frog  Common newt  Great crested newt
# 0   1       A1  600  ...          0            0                   0
# 1   2       A1  700  ...          0            1                   0
# 2   3       A1  200  ...          0            1                   0
# 3   4       A1  300  ...          0            0                   0
# 4   5       A1  600  ...          0            1                   1
#
# [5 rows x 23 columns]

# %%
df_c.tail()
# Out:
#       ID Motorway    SR  ...  Tree frog  Common newt  Great crested newt
# 184  185      S52  2300  ...          0            0                   0
# 185  186      S52   300  ...          0            1                   0
# 186  187      S52   500  ...          0            1                   0
# 187  188      S52   300  ...          0            0                   0
# 188  189      S52   300  ...          0            0                   0
#
# [5 rows x 23 columns]

# %%
#printing the python data type variable
print(df_c.info())
print("\n")
#printing the column and their unique values
for column in df_c:
  print(column)
  print(df_c[column].unique())
  print("\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  189 non-null    int64
#  1   Motorway            189 non-null    object
#  2   SR                  189 non-null    int64
#  3   NR                  189 non-null    int64
#  4   TR                  189 non-null    int64
#  5   VR                  189 non-null    int64
#  6   SUR1                189 non-null    int64
#  7   SUR2                189 non-null    int64
#  8   SUR3                189 non-null    int64
#  9   UR                  189 non-null    int64
#  10  FR                  189 non-null    int64
#  11  OR                  189 non-null    int64
#  12  RR                  189 non-null    int64
#  13  BR                  189 non-null    int64
#  14  MR                  189 non-null    int64
#  15  CR                  189 non-null    int64
# ...
